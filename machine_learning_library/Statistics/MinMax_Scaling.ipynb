# %%
import pandas as pd

# %%
df=pd.read_csv("weight-height.csv")
df
# Out:
#       Gender     Height      Weight
# 0       Male  73.847017  241.893563
# 1       Male  68.781904  162.310473
# 2       Male  74.110105  212.740856
# 3       Male  71.730978  220.042470
# 4       Male  69.881796  206.349801
# ...      ...        ...         ...
# 9995  Female  66.172652  136.777454
# 9996  Female  67.067155  170.867906
# 9997  Female  63.867992  128.475319
# 9998  Female  69.034243  163.852461
# 9999  Female  61.944246  113.649103
#
# [10000 rows x 3 columns]

# %%
max_val=df["Weight"].max()
max_val
# Out:
# 269.989698505106

# %%
min_val=df["Weight"].min()
min_val
# Out:
# 64.700126712753

# %%
MinMax_Scaling=(df["Weight"]-min_val)/(max_val-min_val)
df["MinMax_Scaling"]=MinMax_Scaling

# %%
df.head(50)
# Out:
#    Gender     Height      Weight  MinMax_Scaling
# 0    Male  73.847017  241.893563        0.863139
# 1    Male  68.781904  162.310473        0.475476
# 2    Male  74.110105  212.740856        0.721131
# 3    Male  71.730978  220.042470        0.756699
# 4    Male  69.881796  206.349801        0.689999
# 5    Male  67.253016  152.212156        0.426286
# 6    Male  68.785081  183.927889        0.580778
# 7    Male  68.348516  167.971110        0.503050
# 8    Male  67.018950  175.929440        0.541817
# 9    Male  63.456494  156.399676        0.446684
# 10   Male  71.195382  186.604926        0.593819
# 11   Male  71.640805  213.741169        0.726004
# 12   Male  64.766329  167.127461        0.498941
# 13   Male  69.283070  189.446181        0.607659
# 14   Male  69.243732  186.434168        0.592987
# 15   Male  67.645620  172.186930        0.523586
# 16   Male  72.418317  196.028506        0.639723
# 17   Male  63.974326  172.883470        0.526979
# ...

# %%
df[["Height","Weight"]].min()
# Out:
# Height    54.263133
# Weight    64.700127
# dtype: float64

# %%
df.cov()
# Out:
#                     Height       Weight  MinMax_Scaling
# Height           14.803473   114.242656        0.556495
# Weight          114.242656  1030.951855        5.021940
# MinMax_Scaling    0.556495     5.021940        0.024463
