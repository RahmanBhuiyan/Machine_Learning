# %%
import pandas as pd

# %%
df=pd.read_csv("pivot_data.csv")

# %%
df
# Out:
#        date      city  event  windspeed  temperature
# 0  1/1/2017        us   Rain          6           32
# 1  1/4/2017  new york  Sunny          8           34
# 2  1/4/2017    canada  Sunny          6           20
# 3  1/4/2017     mumbi   Rain          9           12
# 4  1/4/2017        BD   Rain         10           34
# 5  1/4/2017  new york  Sunny          7           28
# 6  1/4/2017    canada  Sunny          4           36
# 7  1/4/2017        us   Rain         11           32
# 8  1/4/2017        BD   Rain          7           45

# %%
chill=pd.melt(df,id_vars=["event"])

# %%
chill
# Out:
#     event     variable     value
# 0    Rain         date  1/1/2017
# 1   Sunny         date  1/4/2017
# 2   Sunny         date  1/4/2017
# 3    Rain         date  1/4/2017
# 4    Rain         date  1/4/2017
# 5   Sunny         date  1/4/2017
# 6   Sunny         date  1/4/2017
# 7    Rain         date  1/4/2017
# 8    Rain         date  1/4/2017
# 9    Rain         city        us
# 10  Sunny         city  new york
# 11  Sunny         city    canada
# 12   Rain         city     mumbi
# 13   Rain         city        BD
# 14  Sunny         city  new york
# 15  Sunny         city    canada
# 16   Rain         city        us
# 17   Rain         city        BD
# 18   Rain    windspeed         6
# 19  Sunny    windspeed         8
# 20  Sunny    windspeed         6
# 21   Rain    windspeed         9
# 22   Rain    windspeed        10
# 23  Sunny    windspeed         7
# 24  Sunny    windspeed         4
# 25   Rain    windspeed        11
# 26   Rain    windspeed         7
# ...

# %%
chill[chill["variable"]=="city"]
# Out:
#     event variable     value
# 9    Rain     city        us
# 10  Sunny     city  new york
# 11  Sunny     city    canada
# 12   Rain     city     mumbi
# 13   Rain     city        BD
# 14  Sunny     city  new york
# 15  Sunny     city    canada
# 16   Rain     city        us
# 17   Rain     city        BD

# %%
chill=pd.melt(df,id_vars=["event"],var_name="city",value_name="tmp")

# %%
chill
# Out:
#     event         city       tmp
# 0    Rain         date  1/1/2017
# 1   Sunny         date  1/4/2017
# 2   Sunny         date  1/4/2017
# 3    Rain         date  1/4/2017
# 4    Rain         date  1/4/2017
# 5   Sunny         date  1/4/2017
# 6   Sunny         date  1/4/2017
# 7    Rain         date  1/4/2017
# 8    Rain         date  1/4/2017
# 9    Rain         city        us
# 10  Sunny         city  new york
# 11  Sunny         city    canada
# 12   Rain         city     mumbi
# 13   Rain         city        BD
# 14  Sunny         city  new york
# 15  Sunny         city    canada
# 16   Rain         city        us
# 17   Rain         city        BD
# 18   Rain    windspeed         6
# 19  Sunny    windspeed         8
# 20  Sunny    windspeed         6
# 21   Rain    windspeed         9
# 22   Rain    windspeed        10
# 23  Sunny    windspeed         7
# 24  Sunny    windspeed         4
# 25   Rain    windspeed        11
# 26   Rain    windspeed         7
# ...
