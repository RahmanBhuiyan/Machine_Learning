# %%
import pandas as pd

# %%
df=pd.read_csv("weather_data.csv")

# %%
df.head()
# Out:
#    Unnamed: 0             location        max         Mini     avraje
# 0           0  2021-04-15T00:00:00  13.358188  -0.53181195  6.6452713
# 1           1  2021-04-16T00:00:00  15.658188     0.738188   9.309438
# 2           2  2021-04-17T00:00:00  18.918188    2.1681879  11.637353
# 3           3  2021-04-18T00:00:00   8.478188  -0.21181196  2.8898554
# 4           4  2021-04-19T00:00:00   4.568188    -2.361812   1.106938

# %%
df=pd.read_csv("weather_data.csv",parse_dates=["location"])

# %%
# df=pd.to_csv("weather_data.csv",index=False)
df
# Out:
#     Unnamed: 0             location  \
# 0            0  2021-04-15T00:00:00
# 1            1  2021-04-16T00:00:00
# 2            2  2021-04-17T00:00:00
# 3            3  2021-04-18T00:00:00
# 4            4  2021-04-19T00:00:00
# 5            5  2021-04-20T00:00:00
# 6            6  2021-04-21T00:00:00
# 7            7  2021-04-22T00:00:00
# 8            8  2021-04-23T00:00:00
# 9            9  2021-04-24T00:00:00
# 10          10  2021-04-25T00:00:00
# 11          11  2021-04-26T00:00:00
# 12          12  2021-04-27T00:00:00
# 13          13  2021-04-28T00:00:00
# 14          14  2021-04-29T00:00:00
# 15          15        not available
# 16          16                  asl
# 17          17                  lat
# 18          18                level
# 19          19        not available
# 20          20           resolution
# 21          21            timestamp
# 22          22                 unit
# 23          23             variable
#
# ...

# %%
type(df.location[0])
# Out:
# str

# %%
df = pd.DataFrame({'date':["location"]})

# %%
# pd.to_datetime(df['date'])
# df

# %%
df.dtypes
# Out:
# date    object
# dtype: object

# %%
df
# Out:
#        date
# 0  location

# %%
# df=pd.read_csv("weather_data.csv")

# %%
# df

# %%
df.dtypes
# Out:
# date    object
# dtype: object

# %%
# pd.to_datetime(df['date'])

# %%
df.dtypes
# Out:
# date    object
# dtype: object

# %%
# df['date'].astype('datetime64')

# %%
chill=pd.read_csv("missing_data.csv")

# %%
chill
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017         32.0        6.0   Rain
# 1  1/4/2017          NaN        NaN    NaN
# 2  1/4/2017          NaN        6.0  Sunny
# 3  1/4/2017         12.0        9.0   Rain
# 4  1/4/2017          NaN        NaN    NaN
# 5  1/4/2017         28.0        NaN  Sunny
# 6  1/4/2017          NaN        7.0    NaN
# 7  1/4/2017         32.0        NaN   Rain
# 8  1/4/2017         22.0        7.0    NaN

# %%
chill=pd.read_csv("missing_data.csv",parse_dates=["day"])

# %%
chill.dtypes
# Out:
# day            datetime64[ns]
# temperature           float64
# windspeed             float64
# event                  object
# dtype: object

# %%
chill
# Out:
#          day  temperature  windspeed  event
# 0 2017-01-01         32.0        6.0   Rain
# 1 2017-01-04          NaN        NaN    NaN
# 2 2017-01-04          NaN        6.0  Sunny
# 3 2017-01-04         12.0        9.0   Rain
# 4 2017-01-04          NaN        NaN    NaN
# 5 2017-01-04         28.0        NaN  Sunny
# 6 2017-01-04          NaN        7.0    NaN
# 7 2017-01-04         32.0        NaN   Rain
# 8 2017-01-04         22.0        7.0    NaN

# %%
chill.set_index("day",inplace=True)

# %%
chill
# Out:
#             temperature  windspeed  event
# day
# 2017-01-01         32.0        6.0   Rain
# 2017-01-04          NaN        NaN    NaN
# 2017-01-04          NaN        6.0  Sunny
# 2017-01-04         12.0        9.0   Rain
# 2017-01-04          NaN        NaN    NaN
# 2017-01-04         28.0        NaN  Sunny
# 2017-01-04          NaN        7.0    NaN
# 2017-01-04         32.0        NaN   Rain
# 2017-01-04         22.0        7.0    NaN

# %%
day=chill.fillna(2.0)

# %%
day
# Out:
#             temperature  windspeed  event
# day
# 2017-01-01         32.0        6.0   Rain
# 2017-01-04          2.0        2.0      2
# 2017-01-04          2.0        6.0  Sunny
# 2017-01-04         12.0        9.0   Rain
# 2017-01-04          2.0        2.0      2
# 2017-01-04         28.0        2.0  Sunny
# 2017-01-04          2.0        7.0      2
# 2017-01-04         32.0        2.0   Rain
# 2017-01-04         22.0        7.0      2

# %%
day=chill.fillna({
    "temperature":0,
    "windspeed":2.0,
    "event":"no event"
})

# %%
day
# Out:
#             temperature  windspeed     event
# day
# 2017-01-01         32.0        6.0      Rain
# 2017-01-04          0.0        2.0  no event
# 2017-01-04          0.0        6.0     Sunny
# 2017-01-04         12.0        9.0      Rain
# 2017-01-04          0.0        2.0  no event
# 2017-01-04         28.0        2.0     Sunny
# 2017-01-04          0.0        7.0  no event
# 2017-01-04         32.0        2.0      Rain
# 2017-01-04         22.0        7.0  no event

# %%
okk=chill.fillna(method='ffill')

# %%
okk
# Out:
#             temperature  windspeed  event
# day
# 2017-01-01         32.0        6.0   Rain
# 2017-01-04         32.0        6.0   Rain
# 2017-01-04         32.0        6.0  Sunny
# 2017-01-04         12.0        9.0   Rain
# 2017-01-04         12.0        9.0   Rain
# 2017-01-04         28.0        9.0  Sunny
# 2017-01-04         28.0        7.0  Sunny
# 2017-01-04         32.0        7.0   Rain
# 2017-01-04         22.0        7.0   Rain

# %%
day=okk.fillna(method='ffill',axis="columns")
day
# Out:
#            temperature windspeed  event
# day
# 2017-01-01          32         6   Rain
# 2017-01-04          32         6   Rain
# 2017-01-04          32         6  Sunny
# 2017-01-04          12         9   Rain
# 2017-01-04          12         9   Rain
# 2017-01-04          28         9  Sunny
# 2017-01-04          28         7  Sunny
# 2017-01-04          32         7   Rain
# 2017-01-04          22         7   Rain

# %%
okk=chill.fillna(method='ffill',limit=1)

# %%
okk
# Out:
#             temperature  windspeed  event
# day
# 2017-01-01         32.0        6.0   Rain
# 2017-01-04         32.0        6.0   Rain
# 2017-01-04          NaN        6.0  Sunny
# 2017-01-04         12.0        9.0   Rain
# 2017-01-04         12.0        9.0   Rain
# 2017-01-04         28.0        NaN  Sunny
# 2017-01-04         28.0        7.0  Sunny
# 2017-01-04         32.0        7.0   Rain
# 2017-01-04         22.0        7.0   Rain

# %%
z=chill.interpolate(method="time")

# %%
z
# Out:
#             temperature  windspeed  event
# day
# 2017-01-01    32.000000   6.000000   Rain
# 2017-01-04    25.333333   6.000000    NaN
# 2017-01-04    18.666667   6.000000  Sunny
# 2017-01-04    12.000000   9.000000   Rain
# 2017-01-04    20.000000   8.333333    NaN
# 2017-01-04    28.000000   7.666667  Sunny
# 2017-01-04    30.000000   7.000000    NaN
# 2017-01-04    32.000000   7.000000   Rain
# 2017-01-04    22.000000   7.000000    NaN

# %%
z=chill.dropna(how="all")
z
# Out:
#             temperature  windspeed  event
# day
# 2017-01-01         32.0        6.0   Rain
# 2017-01-04          NaN        6.0  Sunny
# 2017-01-04         12.0        9.0   Rain
# 2017-01-04         28.0        NaN  Sunny
# 2017-01-04          NaN        7.0    NaN
# 2017-01-04         32.0        NaN   Rain
# 2017-01-04         22.0        7.0    NaN

# %%
z=chill.dropna(thresh=1)
z
# Out:
#             temperature  windspeed event
# day
# 2017-01-01         32.0        6.0  Rain
# 2017-01-04         12.0        9.0  Rain

# %%
dt = pd.date_range("01-01-2017","01-11-2017")
idx = pd.DatetimeIndex(dt)
df=df.reindex(idx)
df
# Out:
#            date
# 2017-01-01  NaN
# 2017-01-02  NaN
# 2017-01-03  NaN
# 2017-01-04  NaN
# 2017-01-05  NaN
# 2017-01-06  NaN
# 2017-01-07  NaN
# 2017-01-08  NaN
# 2017-01-09  NaN
# 2017-01-10  NaN
# 2017-01-11  NaN
