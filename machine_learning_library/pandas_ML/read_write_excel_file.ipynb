# %%
import pandas as pd

# %%
df = pd.read_excel("weather_data.xlsx","Sheet1")

# %%
df=df.to_excel("weather_data.xlsx",index=False)

# %%
df

# %%
def convert_Excel(cell):
    if cell=="not available":
        return "chill bro"
    if cell =="n.a.":
        return None
    return cell

df = pd.read_excel("weather_data.xlsx","Sheet1",converters={
    "Excel":convert_Excel,
    "tmp":convert_Excel
})

# %%
df
# Out:
#                location                                        Excel  \
# 0                   lat                                      51.3332
# 1                   lon                                     -110.625
# 2                   asl                                      763.029
# 3              variable                                  Temperature
# 4                  unit                                           °C
# 5                 level                      2 m elevation corrected
# 6            resolution                                        daily
# 7           aggregation                                      Maximum
# 8             timestamp  Excel Temperature [2 m elevation corrected]
# 9   2021-04-15 00:00:00                                      13.3582
# 10  2021-04-16 00:00:00                                      15.6582
# 11  2021-04-17 00:00:00                                      18.9182
# 12  2021-04-18 00:00:00                                      8.47819
# ...

# %%
df=df.to_excel("new_weather_data.xlsx",sheet_name="stocks",index=False)

# %%
df

# %%
df.to_excel("new_weather_data.xlsx",sheet_name="stocks",startrow=2,startcol=1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-ac31afe76fb3> in <module>
# ----> 1 df.to_excel("new_weather_data.xlsx",sheet_name="stocks",startrow=2,startcol=1)
#
# AttributeError: 'NoneType' object has no attribute 'to_excel'

# %%
df_stocks = pd.DataFrame({
    'tickers': ['GOOGL', 'WMT', 'MSFT'],
    'price': [845, 65, 64 ],
    'pe': [30.37, 14.26, 30.97],
    'eps': [27.82, 4.61, 2.12]
})

df_weather =  pd.DataFrame({
    'day': ['1/1/2017','1/2/2017','1/3/2017'],
    'temperature': [32,35,28],
    'event': ['Rain', 'Sunny', 'Snow']
})

# %%
with pd.ExcelWriter('stocks_weather.xlsx') as writer:
    df_stocks.to_excel(writer, sheet_name="stocks")
    df_weather.to_excel(writer, sheet_name="weather")
