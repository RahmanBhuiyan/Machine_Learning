# %%
import pandas as pd

# %%
#change columns name if there is no columns
# df=pd.read_csv("weather_data.csv",header=None,names=["names","max_tmp","min_tmp","abras_tmp"])
df=pd.read_csv("weather_data.csv",nrows=3)
# .head(3) or nrows=3

# %%
df
# Out:
#               location        max      Mini     avraje
# 0  2021-04-15T00:00:00  13.358188 -0.531812   6.645271
# 1  2021-04-16T00:00:00  15.658188  0.738188   9.309438
# 2  2021-04-17T00:00:00  18.918188  2.168188  11.637353

# %%
df=pd.read_csv("weather_data.csv",na_values=["n.a."])

# %%
df
# Out:
#                location                                          max  \
# 0   2021-04-15T00:00:00                                    13.358188
# 1   2021-04-16T00:00:00                                    15.658188
# 2   2021-04-17T00:00:00                                    18.918188
# 3   2021-04-18T00:00:00                                     8.478188
# 4   2021-04-19T00:00:00                                     4.568188
# 5   2021-04-20T00:00:00                                     8.828188
# 6   2021-04-21T00:00:00                                    16.268188
# 7   2021-04-22T00:00:00                                    10.148188
# 8   2021-04-23T00:00:00                                    5.7581882
# 9   2021-04-24T00:00:00                                     7.798188
# 10  2021-04-25T00:00:00                                     9.418188
# 11  2021-04-26T00:00:00                                    13.978188
# 12  2021-04-27T00:00:00                                    16.598188
# ...

# %%
df=pd.read_csv("weather_data.csv",na_values={
"location":["not available","n.a."],
"max":["n.a",-1]
})

# %%
df
# Out:
#                location                                          max  \
# 0   2021-04-15T00:00:00                                    13.358188
# 1   2021-04-16T00:00:00                                    15.658188
# 2   2021-04-17T00:00:00                                    18.918188
# 3   2021-04-18T00:00:00                                     8.478188
# 4   2021-04-19T00:00:00                                     4.568188
# 5   2021-04-20T00:00:00                                     8.828188
# 6   2021-04-21T00:00:00                                    16.268188
# 7   2021-04-22T00:00:00                                    10.148188
# 8   2021-04-23T00:00:00                                    5.7581882
# 9   2021-04-24T00:00:00                                     7.798188
# 10  2021-04-25T00:00:00                                     9.418188
# 11  2021-04-26T00:00:00                                    13.978188
# 12  2021-04-27T00:00:00                                    16.598188
# ...

# %%
df.to_csv("new.csv",index=False)

# %%
df
# Out:
#                location                                          max  \
# 0   2021-04-15T00:00:00                                    13.358188
# 1   2021-04-16T00:00:00                                    15.658188
# 2   2021-04-17T00:00:00                                    18.918188
# 3   2021-04-18T00:00:00                                     8.478188
# 4   2021-04-19T00:00:00                                     4.568188
# 5   2021-04-20T00:00:00                                     8.828188
# 6   2021-04-21T00:00:00                                    16.268188
# 7   2021-04-22T00:00:00                                    10.148188
# 8   2021-04-23T00:00:00                                    5.7581882
# 9   2021-04-24T00:00:00                                     7.798188
# 10  2021-04-25T00:00:00                                     9.418188
# 11  2021-04-26T00:00:00                                    13.978188
# 12  2021-04-27T00:00:00                                    16.598188
# ...

# %%
df.columns
# Out:
# Index(['location', 'max', 'Mini', 'avraje'], dtype='object')

# %%
# df=df.to_csv("weather_data.csv",columns=["location","max"])
# weather_data.loc[:,"max"]

# %%
df
# Out:
#                location                                          max  \
# 0   2021-04-15T00:00:00                                    13.358188
# 1   2021-04-16T00:00:00                                    15.658188
# 2   2021-04-17T00:00:00                                    18.918188
# 3   2021-04-18T00:00:00                                     8.478188
# 4   2021-04-19T00:00:00                                     4.568188
# 5   2021-04-20T00:00:00                                     8.828188
# 6   2021-04-21T00:00:00                                    16.268188
# 7   2021-04-22T00:00:00                                    10.148188
# 8   2021-04-23T00:00:00                                    5.7581882
# 9   2021-04-24T00:00:00                                     7.798188
# 10  2021-04-25T00:00:00                                     9.418188
# 11  2021-04-26T00:00:00                                    13.978188
# 12  2021-04-27T00:00:00                                    16.598188
# ...

# %%
df=df.to_csv("new.csv",header=False)

# %%
df
