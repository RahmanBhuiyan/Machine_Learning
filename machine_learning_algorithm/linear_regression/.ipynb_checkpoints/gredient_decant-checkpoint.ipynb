# %%
import pandas as pd

# %%
data=pd.read_csv("homeprices.csv")
data
# Out:
#    area  price
# 0  2600  55000
# 1  3000  56500
# 2  3200  61000
# 3  3600  68000
# 4  4000  72000
# 5  5000  71000
# 6  2500  40000
# 7  2700  38000
# 8  1200  17000
# 9  1000  17900

# %%
x=data["area"]
y=data["price"]

# %%
def Gradient_Descent(x,y):
    m_slope=c_intercept=0
    n=len(x)
    iteration=1000
    learning_rate=0.08
    for i in range(iteration):
        y_pred=m_slope*x+c_intercept
        #cost function (actual_value-pred_value)**2
        cost_function=(1/n)*sum([val**2 for val in(y-y_pred)])
        
        
        #derivative in cost function d/dm
        m_dv=-(2/n)*sum(x*(y-y_pred))
        #derivative in cost function d/dc
        c_dv=-(2/n)*sum(y-y_pred)
        
        
        #update value of m(slope) and c(intercept)
        m_slope=m_slope - learning_rate * m_dv
        c_intercept=c_intercept - learning_rate * c_dv
        
        print("m= ",m_slope,"c= ",c_intercept,"cost= ",cost_function)
Gradient_Descent(x,y)
# Out:
# m=  26182400.0 c=  7942.400000000001 cost=  2844066000.0
# m=  -40190982591057.92 c=  -12064835305.984001 cost=  6.576852990101987e+21
# m=  6.169473128509727e+19 c=  1.8519994643505776e+16 cost=  1.5497335686226909e+34
# m=  -9.470382715115793e+25 c=  -2.8428916619377314e+22 cost=  3.651707187815365e+46
# m=  1.453740812263311e+32 c=  4.363949967096363e+28 cost=  8.604682543847651e+58
# m=  -2.231549043806675e+38 c=  -6.698833997191365e+34 cost=  2.0275602032782711e+71
# m=  3.4255151213382254e+44 c=  1.0282972366840602e+41 cost=  4.7776316638865343e+83
# m=  -5.258299780183274e+50 c=  -1.5784765041429754e+47 cost=  1.1257749229278255e+96
# m=  8.071695963634726e+56 c=  2.423023212788189e+53 cost=  2.6527142866056864e+108
# m=  -1.2390369216850985e+63 c=  -3.719435464703383e+59 cost=  6.250710460010007e+120
# m=  1.9019701686181586e+69 c=  5.709479010799143e+65 cost=  1.4728831315215937e+133
# m=  -2.9195986487582428e+75 c=  -8.764273741030107e+71 cost=  3.4706210326008006e+145
# m=  4.4816981940489385e+81 c=  1.345350321148804e+78 cost=  8.177981059154015e+157
# m=  -6.8795821340321155e+87 c=  -2.065165397723481e+84 cost=  1.9270146056184076e+170
# m=  1.056042783107074e+94 c=  3.170109712623066e+90 cost=  4.5407115318640807e+182
# m=  -1.6210670038165554e+100 c=  -4.86624248166524e+96 cost=  1.0699483623782291e+195
# m=  2.4884012967080147e+106 c=  7.469872665943004e+102 cost=  2.521167641067674e+207
# m=  -3.819793382309107e+112 c=  -1.1466546900537494e+109 cost=  5.940741158982937e+219
# m=  5.863532342164871e+118 c=  1.760159827378097e+115 cost=  1.399843665417194e+232
# m=  -9.000751634066072e+124 c=  -2.7019142247353178e+121 cost=  3.298514840434701e+244
# m=  1.3816506032647221e+131 c=  4.147544083369697e+127 cost=  7.77243946689243e+256
# m=  -2.1208877515037076e+137 c=  -6.366642495906811e+133 cost=  1.831455008962327e+269
# m=  3.255645706555386e+143 c=  9.773045410949388e+139 cost=  4.3155401391556716e+281
# m=  -4.997543580087007e+149 c=  -1.5002007206449074e+146 cost=  1.016890210326037e+294
# m=  7.671424990925673e+155 c=  2.3028668215354877e+152 cost=  2.396144321482885e+306
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# <ipython-input-38-25f1ae030b35> in <module>
#      21
#      22         print("m= ",m_slope,"c= ",c_intercept,"cost= ",cost_function)
# ---> 23 Gradient_Descent(x,y)
#      24
#
# <ipython-input-38-25f1ae030b35> in Gradient_Descent(x, y)
#       7         y_pred=m_slope*x+c_intercept
#       8         #cost function (actual_value-pred_value)**2
# ----> 9         cost_function=(1/n)*sum([val**2 for val in(y-y_pred)])
#      10
#      11
#
# <ipython-input-38-25f1ae030b35> in <listcomp>(.0)
#       7         y_pred=m_slope*x+c_intercept
#       8         #cost function (actual_value-pred_value)**2
# ----> 9         cost_function=(1/n)*sum([val**2 for val in(y-y_pred)])
#      10
#      11
#
# OverflowError: (34, 'Numerical result out of range')
