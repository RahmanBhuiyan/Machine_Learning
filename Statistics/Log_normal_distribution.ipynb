# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib as plt

# %%
df = pd.read_csv("Sales_January_2019.csv")

# %%
# df["Price Each"]
# df["Price Each"] = df["Price Each"].astype(float)
df["Price Each"] = pd.to_numeric(df["Price Each"],errors='coerce')
df.dtypes
# Out:
# Order ID             object
# Product              object
# Quantity Ordered     object
# Price Each          float64
# Order Date           object
# Purchase Address     object
# dtype: object

# %%
g = sns.barplot(x='Price Each',y='Product',data=df)
g.set_xticklabels(g.get_xticklabels(), 
                          rotation=45, 
                          horizontalalignment='right')
# plt.show
# Out:
# <ipython-input-11-6453cc17936a>:2: UserWarning: FixedFormatter should only be used together with FixedLocator
#   g.set_xticklabels(g.get_xticklabels(),
# [Text(0.0, 0, ''),
#  Text(200.0, 0, ''),
#  Text(400.0, 0, ''),
#  Text(600.0, 0, ''),
#  Text(800.0, 0, ''),
#  Text(1000.0, 0, ''),
#  Text(1200.0, 0, ''),
#  Text(1400.0, 0, ''),
#  Text(1600.0, 0, ''),
#  Text(1800.0, 0, '')]

# %%
sns.distplot(x=df["Price Each"], kde = True)
# Out:
# <AxesSubplot:ylabel='Density'>
